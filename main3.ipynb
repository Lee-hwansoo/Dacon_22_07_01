# %%
import pandas as pd
train_df = pd.read_csv('./data/train.csv')
val_df = pd.read_csv('./data/val.csv')
test_df = pd.read_csv('./data/test.csv')
# val_df 의 오염도 계산
# Class=0 정상거래, Class=1 부정거래
val_normal, val_fraud = val_df['Class'].value_counts()
val_contamination = val_fraud / val_normal
print(f'Validation contamination : [{val_contamination}]')
# Out:
# Validation contamination : [0.0010551491277433877]

# %%
from pycaret.anomaly import *
s = setup(data = train_df.drop(columns=['ID']),remove_multicollinearity = True,multicollinearity_threshold = 0.90, normalize = True,silent= True)
# Out:
# <style type="text/css">
# #T_32a0b_row21_col1, #T_32a0b_row34_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_32a0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32a0b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_32a0b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32a0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32a0b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_32a0b_row0_col1" class="data row0 col1" >1644</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32a0b_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_32a0b_row1_col1" class="data row1 col1" >(113842, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32a0b_row2_col0" class="data row2 col0" >Missing Values</td>
#       <td id="T_32a0b_row2_col1" class="data row2 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32a0b_row3_col0" class="data row3 col0" >Numeric Features</td>
#       <td id="T_32a0b_row3_col1" class="data row3 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32a0b_row4_col0" class="data row4 col0" >Categorical Features</td>
#       <td id="T_32a0b_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_32a0b_row5_col0" class="data row5 col0" >Ordinal Features</td>
#       <td id="T_32a0b_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_32a0b_row6_col0" class="data row6 col0" >High Cardinality Features</td>
#       <td id="T_32a0b_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_32a0b_row7_col0" class="data row7 col0" >High Cardinality Method</td>
#       <td id="T_32a0b_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_32a0b_row8_col0" class="data row8 col0" >Transformed Data</td>
#       <td id="T_32a0b_row8_col1" class="data row8 col1" >(113842, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_32a0b_row9_col0" class="data row9 col0" >CPU Jobs</td>
#       <td id="T_32a0b_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_32a0b_row10_col0" class="data row10 col0" >Use GPU</td>
#       <td id="T_32a0b_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_32a0b_row11_col0" class="data row11 col0" >Log Experiment</td>
#       <td id="T_32a0b_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_32a0b_row12_col0" class="data row12 col0" >Experiment Name</td>
#       <td id="T_32a0b_row12_col1" class="data row12 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_32a0b_row13_col0" class="data row13 col0" >USI</td>
#       <td id="T_32a0b_row13_col1" class="data row13 col1" >2897</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_32a0b_row14_col0" class="data row14 col0" >Imputation Type</td>
#       <td id="T_32a0b_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_32a0b_row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#       <td id="T_32a0b_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_32a0b_row16_col0" class="data row16 col0" >Numeric Imputer</td>
#       <td id="T_32a0b_row16_col1" class="data row16 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_32a0b_row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_32a0b_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_32a0b_row18_col0" class="data row18 col0" >Categorical Imputer</td>
#       <td id="T_32a0b_row18_col1" class="data row18 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_32a0b_row19_col0" class="data row19 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_32a0b_row19_col1" class="data row19 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_32a0b_row20_col0" class="data row20 col0" >Unknown Categoricals Handling</td>
#       <td id="T_32a0b_row20_col1" class="data row20 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_32a0b_row21_col0" class="data row21 col0" >Normalize</td>
#       <td id="T_32a0b_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_32a0b_row22_col0" class="data row22 col0" >Normalize Method</td>
#       <td id="T_32a0b_row22_col1" class="data row22 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_32a0b_row23_col0" class="data row23 col0" >Transformation</td>
#       <td id="T_32a0b_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_32a0b_row24_col0" class="data row24 col0" >Transformation Method</td>
#       <td id="T_32a0b_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_32a0b_row25_col0" class="data row25 col0" >PCA</td>
#       <td id="T_32a0b_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_32a0b_row26_col0" class="data row26 col0" >PCA Method</td>
#       <td id="T_32a0b_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_32a0b_row27_col0" class="data row27 col0" >PCA Components</td>
#       <td id="T_32a0b_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_32a0b_row28_col0" class="data row28 col0" >Ignore Low Variance</td>
#       <td id="T_32a0b_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_32a0b_row29_col0" class="data row29 col0" >Combine Rare Levels</td>
#       <td id="T_32a0b_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32a0b_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_32a0b_row30_col0" class="data row30 col0" >Rare Level Threshold</td>
#       <td id="T_32a0b_row3

# %%
from pycaret.classification import *
best_3 = compare_models(exclude = None, include = None, fold = 10, round = 4, sort='F1',n_select=3,budget_time=0,turbo=False,verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\git\dacon\hwansoo3.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/git/dacon/hwansoo3.ipynb#ch0000002?line=0'>1</a> from pycaret.classification import *
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/git/dacon/hwansoo3.ipynb#ch0000002?line=1'>2</a> best_3 = compare_models(exclude = None, include = None, fold = 10, round = 4, sort='F1',n_select=3,budget_time=0,turbo=False,verbose=True)
#
# File c:\Users\user\anaconda3\envs\pybook\lib\site-packages\pycaret\classification.py:823, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, display, parallel)
#     820     del params["parallel"]
#     821     return parallel.compare_models(compare_models, params)
# --> 823 return pycaret.internal.tabular.compare_models(
#     824     include=include,
#     825     exclude=exclude,
#     826     fold=fold,
#     827     round=round,
#     828     cross_validation=cross_validation,
#     829     sort=sort,
#     830     n_select=n_select,
#     831     budget_time=budget_time,
#     832     turbo=turbo,
#     833     errors=errors,
#     834     fit_kwargs=fit_kwargs,
#     835     groups=groups,
#     836     experiment_custom_tags=experiment_custom_tags,
#     837     probability_threshold=probability_threshold,
#     838     verbose=verbose,
#     839     display=display,
#     840 )
#
# File c:\Users\user\anaconda3\envs\pybook\lib\site-packages\pycaret\internal\tabular.py:2019, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, display)
#    2017     sort = _get_metric(sort)
#    2018     if sort is None:
# -> 2019         raise ValueError(
#    2020             f"Sort method not supported. See docstring for list of available parameters."
#    2021         )
#    2023 # checking errors parameter
#    2024 possible_errors = ["ignore", "raise"]
#
# ValueError: Sort method not supported. See docstring for list of available parameters.

# %%
models()
# Out:
#                                         Name                    Reference
# ID
# abod            Angle-base Outlier Detection        pyod.models.abod.ABOD
# cluster       Clustering-Based Local Outlier      pyod.models.cblof.CBLOF
# cof         Connectivity-Based Local Outlier          pyod.models.cof.COF
# iforest                     Isolation Forest  pyod.models.iforest.IForest
# histogram  Histogram-based Outlier Detection        pyod.models.hbos.HBOS
# knn             K-Nearest Neighbors Detector          pyod.models.knn.KNN
# lof                     Local Outlier Factor          pyod.models.lof.LOF
# svm                   One-class SVM detector      pyod.models.ocsvm.OCSVM
# pca             Principal Component Analysis          pyod.models.pca.PCA
# mcd           Minimum Covariance Determinant          pyod.models.mcd.MCD
# sod               Subspace Outlier Detection          pyod.models.sod.SOD
# sos             Stochastic Outlier Selection          pyod.models.sos.SOS

# %% [markdown]
# ## Evaluation : Validation set
